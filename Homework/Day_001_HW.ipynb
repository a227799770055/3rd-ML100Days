# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = (sum(abs(y - yp)))/ len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    計算MSE
        -y: 實際時
        -yp: 預測值
    """
    mse=MSE=(sum((y-yp)**2))/len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 242.754
# The Mean absolute error is 12.156

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 我選定的主題是“Recorded Crime Data at the Police Force Area Level”，主要分析英國不同地區的犯罪發生事件數量與種類。
#
# 1. 你選的這組資料為何重要
# 分析這些犯罪發生率可以幫助了解該區域是否該加派警力，犯罪發生的型態可以用以考慮該區應以哪種警察業務為主。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 該資料由 英國的Office for National Statistics網站取得。
#
# 3. 蒐集而來的資料型態為何
# 資料形式主要以文字紀錄（非結構化）為主，並記錄成表格的方式。
#
# 4. 這組資料想解決的問題如何評估
# 由於該組資料主要是想要視覺話呈現犯罪頻率的分佈情形，所以無法去評估資料問題的好壞與否。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 載客需求數量為核心問題。如果要達成提升業績的目標，首要任務是要分析出該城市的離峰雨尖峰的搭車時間，並找出影響離尖峰時間的因素。影響的因素有很多，假設搭乘計程車的人都是特定人士（eg. 上班族與行動不變的老人），分析這些人的生活模式便成為主要的議題。例如上下班時間上班族的路線規劃或是老人平時需要搭車到醫院或是市場買菜...首先分析主要客群，接著分析這些客群的行為模式，與影響這些模式的潛在因素（eg. 天氣或是節日...）。利用這些資料去找出哪些時間點與地區會有最大的載客需求，並事先增派車輛在那些地方。
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 上下班時間的車流量可以做為判定哪些時間點可能會有較大的載客需求，可以從各區政府的交通局上擷取車流資訊 ；天氣資訊可能會間接的導致大眾想搭計程車的意願，該資料可以從氣象局擷取；此外最重要的是必須分析潛在客戶的行為模式，可以藉由網路問券或是傳統的訪問方式獲得資料；最後還是必須累積真實世界的情況，藉由載客app可以得知每趟載客的時間與地點，在更細去將這些客戶分門別類，並持續收集大量資料來去加入模型中，來去增加模型的預估能力。
#
# 3. 蒐集而來的資料型態為何
# 大多數的資料呈現皆以表格的方式，包括車流量大小、搭車時間、天氣狀況...這些資料都可以數值化並且計算一個相對的數值大小。
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 假設我們在模型中想要去找出不同時間的載客數量，那麼我們可以藉由迴歸分析去對過去的資料進行分析。分析每個時間點的載客需求數量，並分析哪些變因為主要影響因子。對於回歸模型的評估，我們可以使用上面提到的MSE、MAE來去算出真實載客數與模型評估的載客數的差異，以判斷我們的模型品質。
